# %%
import requests

# %%
url_1 = "https://content.digitizetheplanet.org/api/protectedarea/9a482446-cab1-4338-9df8-7bb627b339e8/"

# %%
payload = {}
headers = {}

# %%
response_1 = requests.request("GET", url_1, headers=headers, data=payload)

# %%
print(response_1.text)
# Out:
# {"countries":[{"id":1,"name_0":"Germany"}],"states":[{"id":15,"name_1":"Schleswig-Holstein"}],"districts":[{"id":366,"name_2":"Dithmarschen"},{"id":372,"name_2":"Nordfriesland"}],"organization":{"organization":"","division":"","homepage":"","address1":"","address2":"","zip_code":"","city":"","state":"","country":null},"category":{"code":1000,"id":1,"protectedareacategory":"National Park","protectedareacategory_de":"Nationalpark","protectedareacategory_en":"National Park","protectedareacategory_fi":null,"protectedareacategory_fr":null,"protectedareacategory_hu":null,"protectedareacategory_it":null,"protectedareacategory_pt":null,"protectedareacategory_ro":null,"protectedareacategory_sl":null},"legaldocs":[],"parent":{"uuid":null,"osm_id":"","wdpa_id":"","wikidata_id":"","outdooractive_id":"","name_en":"","name_de":"","name_sl":"","date_created":null,"date_modified":null},"children":[],"relatives":[],"picture":null,"picture_caption":null,"picture_caption_de":null,"picture_caption_en":n
# ...

# %% [markdown]
# ### 1. What is the name of the protected area with UUID '9a482446-cab1-4338-9df8-7bb627b339e8'?
# Schleswig-Holsteinisches Wattenmeer

# %% [markdown]
# ### 2. What is the name of the source organization for the geometry information?
# Bundesamt für Naturschutz

# %% [markdown]
# ### 3. Which category is the protected area of?
# National Park

# %%
url_2 = "https://content.digitizetheplanet.org/api/protectedarearule/149/"

# %%
payload = {}
headers = {}

# %%
response_2 = requests.request("GET", url_2, headers=headers, data=payload)

# %%
print(response_2.text)
# Out:
# {"id":149,"activity":{"id":15,"code":9000,"category":{"id":6,"code":9000,"category":"Stay activities","category_en":"Stay activities","category_de":"Aufenthaltsaktivitäten"},"activity":"Camping","activity_de":"Zelten","activity_en":"Camping"},"activityplace":{"id":1,"place":"Total area of the territory","place_en":"Total area of the territory","place_de":"Gesamte Fläche des Gebietes"},"activitypermission":{"id":2,"permission":"forbidden","permission_en":"forbidden","permission_de":"verboten"},"weathercondition":null,"season":null,"daytime":null,"user":{"id":20,"organization":"Sielmann Stiftung","division":null,"homepage":"https://www.sielmann-stiftung.de/","address1":null,"address2":null,"zip_code":null,"city":null,"state":null,"country":""},"icons":[{"id":110,"name":"dtp_camping_forbidden_regular","file":"https://content.digitizetheplanet.org/archives/icons/dtp_camping_forbidden_regular.svg","style":"regular","general":null,"activity":15,"activityplace":null,"activitypermission":2,"
# ...

# %%
url_3 = "https://content.digitizetheplanet.org/api/protectedarea/c9c5ec51-1c26-420b-91fc-e3757083b178/"

# %%
response_3 = requests.request("GET", url_3, headers=headers, data=payload)

# %%
print(response_3.text)
# Out:
# {"countries":[{"id":1,"name_0":"Germany"}],"states":[{"id":4,"name_1":"Brandenburg"}],"districts":[{"id":149,"name_2":"Havelland"},{"id":155,"name_2":"Potsdam"}],"organization":{"id":29,"organization":"Sielmann Stiftung","division":null,"homepage":"https://www.sielmann-stiftung.de/","address1":null,"address2":null,"zip_code":null,"city":null,"state":null,"country":""},"category":{"code":2000,"id":2,"protectedareacategory":"Nature Reserve","protectedareacategory_de":"Naturschutzgebiet","protectedareacategory_en":"Nature Reserve","protectedareacategory_fi":null,"protectedareacategory_fr":null,"protectedareacategory_hu":null,"protectedareacategory_it":null,"protectedareacategory_pt":null,"protectedareacategory_ro":null,"protectedareacategory_sl":null},"legaldocs":[{"name":"Verordnung Naturschutzgebiet Ferbitzer Bruch","file":"https://content.digitizetheplanet.org/archives/legaldocs/NSG-VO.FB.DH.kompl..pdf","url":null}],"parent":{"uuid":null,"osm_id":"","wdpa_id":"","wikidata_id":"","out
# ...

# %% [markdown]
# ### 4. What activity, activity place, and activity permission are described by protected area rule with ID '149' and what is the name of the protected area (park) where it applies to?
# Activity: Camping
#
# Activity place: Total area of the territory
#
# Activity permission: forbidden
#
# The name of the protected area (park) where it applies to: Ferbitzer Bruch
